# %% [markdown]
# ## Filter Visualization

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import Model
from numpy import expand_dims
from matplotlib import pyplot

# %% [markdown]
# ## Filter Visualization

# %%
model = VGG16()
model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ...

# %%
for layer in model.layers:
    if 'conv' in layer.name:
        print(layer.name)
# Out:
# block1_conv1
# block1_conv2
# block2_conv1
# block2_conv2
# block3_conv1
# block3_conv2
# block3_conv3
# block4_conv1
# block4_conv2
# block4_conv3
# block5_conv1
# block5_conv2
# block5_conv3

# %%
for layer in model.layers:
    if 'conv' not in layer.name:
        continue

    filters, biases = layer.get_weights()
    print(layer.name,filters.shape)
# Out:
# block1_conv1 (3, 3, 3, 64)
# block1_conv2 (3, 3, 64, 64)
# block2_conv1 (3, 3, 64, 128)
# block2_conv2 (3, 3, 128, 128)
# block3_conv1 (3, 3, 128, 256)
# block3_conv2 (3, 3, 256, 256)
# block3_conv3 (3, 3, 256, 256)
# block4_conv1 (3, 3, 256, 512)
# block4_conv2 (3, 3, 512, 512)
# block4_conv3 (3, 3, 512, 512)
# block5_conv1 (3, 3, 512, 512)
# block5_conv2 (3, 3, 512, 512)
# block5_conv3 (3, 3, 512, 512)

# %%
filters, biases = model.layers[-1].get_weights()

print(filters.shape)
print(biases.shape)
print(filters)
# Out:
# (4096, 1000)
# (1000,)
# [[ 0.00338803  0.00504329 -0.0032624  ... -0.00584898 -0.00315466
#    0.01366626]
#  [-0.00795877 -0.00110815 -0.00197206 ... -0.00841791 -0.00452075
#   -0.00463977]
#  [ 0.00034271  0.00696493 -0.00256958 ... -0.00680142  0.00583264
#    0.00227   ]
#  ...
#  [-0.00166638  0.01209987 -0.00235068 ...  0.00220267 -0.01347332
#   -0.01866422]
#  [-0.00629507  0.00078151 -0.0070783  ...  0.0162852  -0.0012129
#   -0.00963307]
#  [-0.00330952  0.00706962 -0.01223338 ... -0.00616068 -0.00658735
#    0.01427563]]

# %%
f_min,f_max = filters.min(),filters.max()

filters_result = (filters-filters.min())/(filters-filters.min())

print(f_min)
print(f_max)

# print(filters_result)
# Out:
# -0.035473574
# 0.057255637
# C:\Users\Ripon\AppData\Local\Temp\ipykernel_5092\3178248324.py:3: RuntimeWarning: invalid value encountered in divide
#   filters_result = (filters-filters.min())/(filters-filters.min())

# %%
n_filters , ix = 6,1

for i in range(n_filters):
    f = filters[:,:,:,i]
    for j in range(3):
        ax = pyplot.subplot(n_filters,3,ix)
        ax.set_xticks([])
        ax.set_yticks([])

        pyplot.imshow(f[:,:,j],cmap='gray')
        pyplot.title(f'Filter{i} chanel {j}')
        # pyplot.subplots_adjust(top=0.99,bottom=0.9,hspace=1.5)
        ix+=1

pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 4
#       1 n_filters , ix = 6,1
#       3 for i in range(n_filters):
# ----> 4     f = filters[:,:,:,i]
#       5     for j in range(3):
#       6         ax = pyplot.subplot(n_filters,3,ix)
#
# IndexError: too many indices for array: array is 2-dimensional, but 4 were indexed

# %% [markdown]
# #### Feature map visualization

# %% [markdown]
# #### lower level features

# %%
for i in range(len(model.layers)):
    layer = model.layers[i]
    if 'conv' not in layer.name:
        continue
    print(i,layer.name,layer.output.shape)
# Out:
# 1 block1_conv1 (None, 224, 224, 64)
# 2 block1_conv2 (None, 224, 224, 64)
# 4 block2_conv1 (None, 112, 112, 128)
# 5 block2_conv2 (None, 112, 112, 128)
# 7 block3_conv1 (None, 56, 56, 256)
# 8 block3_conv2 (None, 56, 56, 256)
# 9 block3_conv3 (None, 56, 56, 256)
# 11 block4_conv1 (None, 28, 28, 512)
# 12 block4_conv2 (None, 28, 28, 512)
# 13 block4_conv3 (None, 28, 28, 512)
# 15 block5_conv1 (None, 14, 14, 512)
# 16 block5_conv2 (None, 14, 14, 512)
# 17 block5_conv3 (None, 14, 14, 512)

# %%
import keras

model = keras.Model(inputs=model.inputs,outputs=model.layers[1].output)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,792 (7.00 KB)
#  Trainable params: 1,792 (7.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf

path = 'images.jpeg'
img = tf.keras.utils.load_img(path,target_size=(224,224))

pyplot.imshow(img)

# %%
import numpy as np

img = tf.keras.utils.img_to_array(img)
img = np.expand_dims(img,axis=0)

# %%
img = preprocess_input(img)

# %%
feature_maps = model.predict(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %%
square = 8
ix = 1
for _ in range(square):
    for _ in range(square):
        ax = pyplot.subplot(square,square,ix)
        ax.set_xticks([])
        ax.set_yticks([])

        pyplot.imshow(feature_maps[0,:,:,ix-1],cmap='gray')
        ix+=1

pyplot.show()

# %% [markdown]
# ### Visualize Higher level Feature

# %%
model = VGG16()

# %%
ixs =[2,5,9,13,17]
outputs = [model.layers[i+1].output for i in ixs]

model = Model(inputs= model.inputs,outputs=outputs)

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ...

# %%
feature_maps = model.predict(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 61s 61s/step

# %%
square = 8

for fmap in feature_maps:
    ix = 1
    for _ in range(square):
        for _ in range(square):
            ax = pyplot.subplot(square,square,ix)
            ax.set_xticks([])
            ax.set_yticks([])

            pyplot.imshow(fmap[0,:,:,ix-1],cmap='gray')
            ix+=1

pyplot.show()
